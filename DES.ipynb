# %%
import numpy as np

def toString(binary_string):
    chunks = [binary_string[i:i+8] for i in range(0, len(binary_string), 8)]
    characters = [chr(int(chunk, 2)) for chunk in chunks]
    string = ''.join(characters)
    return string

def toBinary(a):
    l = []
    for i in a:
        l.append(ord(i))
    m = []
    for i in l:
        binary = bin(i)[2:]
        binary = binary.zfill(8)
        m.append(binary)
    return m

def listToString(s):
    str1 = ""
    for ele in s:
        str1 += str(ele)
    return str1

def binaryToDecimal(binary):
    decimal, i = 0, 0
    while(binary != 0):
        dec = binary % 10
        decimal = decimal + dec * pow(2, i)
        binary = binary//10
        i += 1
    return decimal

def decimalToBinary(n):
    res1 =  bin(n).replace("0b","")
    res2 = int(res1)
    num  = ("{:04d}".format(res2))
    return num

def Expansion(r):
    E = [32,1,2,3,4,5,  4,5,6,7,8,9, 8,9,10,11,12,13, 
        12,13,14,15,16,17, 16,17,18,19,20,21, 20,21,22,23,24,25, 
        24,25,26,27,28,29, 28,29,30,31,32,1]
    newArr = [0] * 48
    for i in range(len(E)):
        index = E[i] - 1
        newArr[i] = r[index]
    return newArr

def Xor(key, text):
    array = [0]*48
    for i in range(48):
        val = key[i] ^ int(text[i])
        array[i] = val
    return array

def Xor1(right, fdata):
    array = [0]*32
    for i in range(32):
        val = int(right[i]) ^ fdata[i]
        array[i] = val
    return array

def S_Box(binaryData):
    arr = np.array(binaryData)
    subArr = np.split(arr,8)
    s_1 = [
            [14,4,13,1,2,15,11,8,3,10,6,12,5,9,0,7],
            [0,15,7,4,14,2,13,1,10,6,12,11,9,5,3,8],
            [4,1,14,8,13,6,2,11,15,12,9,7,3,10,5,0],
            [15,12,8,2,4,9,1,7,5,11,3,14,10,0,6,13]
        ]
    s_2 = [
            [15,1,8,14,6,11,3,4,9,7,2,13,12,0,5,10],
            [3,13,4,7,15,2,8,14,12,0,1,10,6,9,11,5],
            [0,14,7,11,10,4,13,1,5,8,12,6,9,3,2,15],
            [13,8,10,1,3,15,4,2,11,6,7,12,0,5,14,9]
        ]
    s_3 = [
            [10,0,9,14,6,3,15,5,1,13,12,7,11,4,2,8],
            [13,7,0,9,3,4,6,10,2,8,5,14,12,11,15,1],
            [13,6,4,9,8,15,3,0,11,1,2,12,5,10,14,7],
            [1,10,13,0,6,9,8,7,4,15,14,3,11,5,2,12]
        ]
    s_4 = [
            [7,13,14,3,0,6,9,10,1,2,8,5,11,12,4,15],
            [13,8,11,5,6,15,0,3,4,7,2,12,1,10,14,9],
            [10,6,9,0,12,11,7,13,15,1,3,14,5,2,8,4],
            [3,15,0,6,10,1,13,8,9,4,5,11,12,7,2,14]
        ]
    s_5 = [
            [2,12,4,1,7,10,11,6,8,5,3,15,13,0,14,9],
            [14,11,2,12,4,7,13,1,5,0,15,10,3,9,8,6],
            [4,2,1,11,10,13,7,8,15,9,12,5,6,3,0,14],
            [11,8,12,7,1,14,2,13,6,15,0,9,10,4,5,3]
        ]
    s_6 = [
            [12,1,10,15,9,2,6,8,0,13,3,4,14,7,5,11],
            [10,15,4,2,7,12,9,5,6,1,13,14,0,11,3,8],
            [9,14,15,5,2,8,12,3,7,0,4,10,1,13,11,6],
            [4,3,2,12,9,5,15,10,11,14,1,7,6,0,8,13]
        ]
    s_7 = [
            [4,11,2,14,15,0,8,13,3,12,9,7,5,10,6,1],
            [13,0,11,7,4,9,1,10,14,3,5,12,2,15,8,6],
            [1,4,11,13,12,3,7,14,10,15,6,8,0,5,9,2],
            [6,11,13,8,1,4,10,7,9,5,0,15,14,2,3,12]
        ]
    s_8 = [
            [13,2,8,4,6,15,11,1,10,9,3,14,5,0,12,7],
            [1,15,13,8,10,3,7,4,12,5,6,11,0,14,9,2],
            [7,11,4,1,9,12,14,2,0,6,10,13,15,3,5,8],
            [2,1,14,7,4,10,8,13,15,12,9,0,3,5,6,11]
        ]
    finalbinary = ''
    for i in range(8):
        r = ''
        c = ''
        r += str(subArr[i][0])
        r += str(subArr[i][5])
        c += str(subArr[i][1])
        c += str(subArr[i][2])
        c += str(subArr[i][3])
        c += str(subArr[i][4])
        row = binaryToDecimal(int(r))
        column = binaryToDecimal(int(c))
        if i == 0:
            finalbinary += decimalToBinary(s_1[row][column])
        elif i == 1:
            finalbinary += decimalToBinary(s_2[row][column])
        elif i == 2:
            finalbinary += decimalToBinary(s_3[row][column])
        elif i == 3:
            finalbinary += decimalToBinary(s_4[row][column])
        elif i == 4:
            finalbinary += decimalToBinary(s_5[row][column])
        elif i == 5:
            finalbinary += decimalToBinary(s_6[row][column])
        elif i == 6:
            finalbinary += decimalToBinary(s_7[row][column])
        elif i == 7:
            finalbinary += decimalToBinary(s_8[row][column])
    return finalbinary

def F_Permutation(binaryData):
    P = [16,7,20,21,29,12,28,17,1,15,23,26,5,18,31,10,2,8,24,14,32,27,3,9,19,13,30,6,22,11,4,25]
    newArr = [0]*32
    for i in range(32):
        index = P[i] - 1
        newArr [i] = int(binaryData[index])
    return newArr

def PC_1(oldKey):
    P = [
        57,49,41,33,25,17,9,1,
        58,50,42,34,26,18,10,2,
        59,51,43,35,27,19,11,3,
        60,52,44,36,63,55,47,39,
        31,23,15,7,62,54,46,38,
        30,22,14,6,61,53,45,37,
        29,21,13,5,28,20,12,4
        ]
    newArr = [0]*56
    for i in range(56):
        index = P[i] - 1
        newArr[i] = oldKey[index]
    return newArr
    
def PC_2(transformedKey):
    P = [
        14,17,11,24,1,5,3,28,
        15,6,21,10,23,19,12,4,
        26,8,16,7,27,20,13,2,
        41,52,31,37,47,55,30,40,
        51,45,33,48,44,49,39,56,
        34,53,46,42,50,36,29,32
    ]
    newArr = [0]*48
    for i in range(48):
        index = P[i] - 1
        newArr[i] = int(transformedKey[index])
    return newArr

def left_shift(data):
    shifted_data = ""
    shifted_data = data[1:] +data[0]
    return shifted_data


def left_shift2(data):
    shifted_data = ""
    char1 = data[0]
    char2 = data[1]
    shifted_data = data[2:] + data[0] + data[1]
    return shifted_data


def Intail_Permutation(binaryData):
    IP = [58,50,42,34,26,18,10,2,60,52,44,36,28,20,12,4,
            62,54,46,38,30,22,14,6,64,56,48,40,32,24,16,8,
            57,49,41,33,25,17,9,1,59,51,43,35,27,19,11,3,
            61,53,45,37,29,21,13,5,63,55,47,39,31,23,15,7]
    newArr = [0]*64
    for i in range(64):
        index = IP[i] - 1
        newArr[i] = binaryData[index]
    return newArr

def Final_permutation(binaryData):
    IP_1 = [40,8,48,16,56,24,64,32,39,7,47,15,55,23,63,31
            ,38,6,46,14,54,22,62,30,37,5,45,13,53,21,61,29,
            36,4,44,12,52,20,60,28,35,3,43,11,51,19,59,27,
            34,2,42,10,50,18,58,26,33,1,41,9,49,17,57,25]
    newArr = [0]*64
    for i in range(64):
        index = IP_1[i]-1
        newArr[i] = binaryData[index]
    return newArr

def Key_genration(fullKey):
    pc_1Key = PC_1(fullKey)

    newArr =np.array(pc_1Key)
    splitedArr = np.split(newArr,2)
    c = splitedArr[0]
    d = splitedArr[1]

    new_C = listToString(c) 
    new_D = listToString(d)
    arr_subkeys = [0] * 16
    for i in range(16) :
        res1 = ''
        res2 = ''
        if i == 0 or i == 1 or i == 8 or i == 15:
            new_C = left_shift(new_C)
            new_D = left_shift(new_D)
        else :
            new_C = left_shift2(new_C)
            new_D = left_shift2(new_D)   
        res1 = new_C + new_D
        
        res2 = PC_2(res1)
        arr_subkeys[i] = res2
    return arr_subkeys


def F_main(rightBinary,Key):
    expansionedData =  Expansion(rightBinary)
    XoredData = Xor(Key,expansionedData)
    s_boxSubstitutioned_Data = S_Box(XoredData)
    f_permutationed_data = F_Permutation(s_boxSubstitutioned_Data)
    return f_permutationed_data




def DES_Encryption(plainText,key):

    binaryData = toBinary(plainText)
    streamBinary = ''
    streamBinary = streamBinary.join(binaryData)
    I_permutedData = Intail_Permutation(streamBinary)
    I_permutedData = np.array(I_permutedData)
    splitedData = np.split(I_permutedData,2)
    leftData = splitedData[0]
    rightData = splitedData[1]
    array_keys = Key_genration(key)
    for i in range(16):
        fun_data = F_main(rightData,array_keys[i])
        xoredData = Xor1(leftData,fun_data)
        leftData = rightData
        rightData = xoredData
    result = rightData + leftData
    finalData = Final_permutation(result)
    finalData = np.array(finalData)
    desData = np.split(finalData,8)
    desData = np.array(desData)
    desData = desData.tolist() 
    f = []
    for i in range(8):
        res = listToString(desData[i])
        f.append(res)
    finalRes = ''

    for y in range(8):
        finalRes += toString(f[y])
    return finalRes

def DES_Decryption(plainText,key):

    binaryData = toBinary(plainText)
    streamBinary = ''
    streamBinary = streamBinary.join(binaryData)
    I_permutedData = Intail_Permutation(streamBinary)
    I_permutedData = np.array(I_permutedData)
    splitedData = np.split(I_permutedData,2)
    leftData = splitedData[0]
    rightData = splitedData[1]
    array_keys = Key_genration(key)
    array_keys1 = array_keys[::-1]
    for i in range(16):
        fun_data = F_main(rightData,array_keys1[i])
        xoredData = Xor1(leftData,fun_data)
        leftData = rightData
        rightData = xoredData
    result = rightData + leftData
    finalData = Final_permutation(result)
    finalData = np.array(finalData)
    desData = np.split(finalData,8)
    desData = np.array(desData)
    desData = desData.tolist() 
    f = []
    for i in range(8):
        res = listToString(desData[i])
        f.append(res)
    finalRes = ''

    for y in range(8):
        finalRes += toString(f[y])
    return finalRes





plaintext =input("Enter your message: ")
key = input("Your key: ")
while(len(key) != 8):
    key=input("The key must be 8 characters! ")
    
key = listToString(toBinary(key))

numZeros = 8 - (len(plaintext) % 8)
for i in range(numZeros):
    plaintext = plaintext + '0'

i = 0
cipher_text = ""
while i < len(plaintext):
    cipher_text += DES_Encryption(plaintext[ i : ( i + 8 ) ], key)
    i += 8
print("Encrypted:", cipher_text)

j = 0
decrypted_text = ""
while j < len(cipher_text):
    decrypted_text += DES_Decryption(cipher_text[ j : ( j + 8 ) ], key)
    j += 8
print("Decrypted:", decrypted_text)
# Out:
# Enter your message: Hello
# Your key: monarchy
# Encrypted: _DGÚY¶9
# Decrypted: Hello000
